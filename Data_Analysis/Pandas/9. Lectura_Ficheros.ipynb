# %%
import pandas as pd
import numpy as np

# %%
datos = {
    'CHN': {'COUNTRY': 'China', 'POP': 1_398.72, 'AREA': 9_596.96,
            'GDP': 12_234.78, 'CONT': 'Asia'},
    'IND': {'COUNTRY': 'India', 'POP': 1_351.16, 'AREA': 3_287.26,
            'GDP': 2_575.67, 'CONT': 'Asia', 'IND_DAY': '1947-08-15'},
    'USA': {'COUNTRY': 'US', 'POP': 329.74, 'AREA': 9_833.52,
            'GDP': 19_485.39, 'CONT': 'N.America',
            'IND_DAY': '1776-07-04'},
    'IDN': {'COUNTRY': 'Indonesia', 'POP': 268.07, 'AREA': 1_910.93,
            'GDP': 1_015.54, 'CONT': 'Asia', 'IND_DAY': '1945-08-17'},
    'BRA': {'COUNTRY': 'Brazil', 'POP': 210.32, 'AREA': 8_515.77,
            'GDP': 2_055.51, 'CONT': 'S.America', 'IND_DAY': '1822-09-07'},
    'PAK': {'COUNTRY': 'Pakistan', 'POP': 205.71, 'AREA': 881.91,
            'GDP': 302.14, 'CONT': 'Asia', 'IND_DAY': '1947-08-14'},
    'NGA': {'COUNTRY': 'Nigeria', 'POP': 200.96, 'AREA': 923.77,
            'GDP': 375.77, 'CONT': 'Africa', 'IND_DAY': '1960-10-01'},
    'BGD': {'COUNTRY': 'Bangladesh', 'POP': 167.09, 'AREA': 147.57,
            'GDP': 245.63, 'CONT': 'Asia', 'IND_DAY': '1971-03-26'},
    'RUS': {'COUNTRY': 'Russia', 'POP': 146.79, 'AREA': 17_098.25,
            'GDP': 1_530.75, 'IND_DAY': '1992-06-12'},
    'MEX': {'COUNTRY': 'Mexico', 'POP': 126.58, 'AREA': 1_964.38,
            'GDP': 1_158.23, 'CONT': 'N.America', 'IND_DAY': '1810-09-16'},
    'JPN': {'COUNTRY': 'Japan', 'POP': 126.22, 'AREA': 377.97,
            'GDP': 4_872.42, 'CONT': 'Asia'},
    'DEU': {'COUNTRY': 'Germany', 'POP': 83.02, 'AREA': 357.11,
            'GDP': 3_693.20, 'CONT': 'Europe'},
    'FRA': {'COUNTRY': 'France', 'POP': 67.02, 'AREA': 640.68,
            'GDP': 2_582.49, 'CONT': 'Europe', 'IND_DAY': '1789-07-14'},
    'GBR': {'COUNTRY': 'UK', 'POP': 66.44, 'AREA': 242.50,
            'GDP': 2_631.23, 'CONT': 'Europe'},
    'ITA': {'COUNTRY': 'Italy', 'POP': 60.36, 'AREA': 301.34,
            'GDP': 1_943.84, 'CONT': 'Europe'},
    'ARG': {'COUNTRY': 'Argentina', 'POP': 44.94, 'AREA': 2_780.40,
            'GDP': 637.49, 'CONT': 'S.America', 'IND_DAY': '1816-07-09'},
    'DZA': {'COUNTRY': 'Algeria', 'POP': 43.38, 'AREA': 2_381.74,
            'GDP': 167.56, 'CONT': 'Africa', 'IND_DAY': '1962-07-05'},
    'CAN': {'COUNTRY': 'Canada', 'POP': 37.59, 'AREA': 9_984.67,
            'GDP': 1_647.12, 'CONT': 'N.America', 'IND_DAY': '1867-07-01'},
    'AUS': {'COUNTRY': 'Australia', 'POP': 25.47, 'AREA': 7_692.02,
            'GDP': 1_408.68, 'CONT': 'Oceania'},
    'KAZ': {'COUNTRY': 'Kazakhstan', 'POP': 18.53, 'AREA': 2_724.90,
            'GDP': 159.41, 'CONT': 'Asia', 'IND_DAY': '1991-12-16'}
}

columnas = ('COUNTRY', 'POP', 'AREA', 'GDP', 'CONT', 'IND_DAY')

# %%
df = pd.DataFrame(datos, index=columnas).T
df
# Out:
#         COUNTRY      POP      AREA       GDP       CONT     IND_DAY
# CHN       China  1398.72   9596.96  12234.78       Asia         NaN
# IND       India  1351.16   3287.26   2575.67       Asia  1947-08-15
# USA          US   329.74   9833.52  19485.39  N.America  1776-07-04
# IDN   Indonesia   268.07   1910.93   1015.54       Asia  1945-08-17
# BRA      Brazil   210.32   8515.77   2055.51  S.America  1822-09-07
# PAK    Pakistan   205.71    881.91    302.14       Asia  1947-08-14
# NGA     Nigeria   200.96    923.77    375.77     Africa  1960-10-01
# BGD  Bangladesh   167.09    147.57    245.63       Asia  1971-03-26
# RUS      Russia   146.79  17098.25   1530.75        NaN  1992-06-12
# MEX      Mexico   126.58   1964.38   1158.23  N.America  1810-09-16
# JPN       Japan   126.22    377.97   4872.42       Asia         NaN
# DEU     Germany    83.02    357.11    3693.2     Europe         NaN
# FRA      France    67.02    640.68   2582.49     Europe  1789-07-14
# ...

# %% [markdown]
# ### Exportando el DF a csv con ```DF.to_csv()```

# %%
df.to_csv('dataDF.csv')

# %% [markdown]
# ### Leyendo el DF exportado con ```pd.read_csv()```

# %%
#dfCSV = pd.read_csv('dataDF.csv')
dfCSV = pd.read_csv('dataDF.csv', index_col=0) #index_col=[index]  le indica al df que columna tomar como indice
dfCSV
# Out:
#         COUNTRY      POP      AREA       GDP       CONT     IND_DAY
# CHN       China  1398.72   9596.96  12234.78       Asia         NaN
# IND       India  1351.16   3287.26   2575.67       Asia  1947-08-15
# USA          US   329.74   9833.52  19485.39  N.America  1776-07-04
# IDN   Indonesia   268.07   1910.93   1015.54       Asia  1945-08-17
# BRA      Brazil   210.32   8515.77   2055.51  S.America  1822-09-07
# PAK    Pakistan   205.71    881.91    302.14       Asia  1947-08-14
# NGA     Nigeria   200.96    923.77    375.77     Africa  1960-10-01
# BGD  Bangladesh   167.09    147.57    245.63       Asia  1971-03-26
# RUS      Russia   146.79  17098.25   1530.75        NaN  1992-06-12
# MEX      Mexico   126.58   1964.38   1158.23  N.America  1810-09-16
# JPN       Japan   126.22    377.97   4872.42       Asia         NaN
# DEU     Germany    83.02    357.11   3693.20     Europe         NaN
# FRA      France    67.02    640.68   2582.49     Europe  1789-07-14
# ...

# %% [markdown]
# #### exportando los DF, y reemplazandolos por otro valor (na_rep=...)

# %%
df.to_csv('NewData.csv', header=True, na_rep='(missing)') #Aquí los valores nulos los reemplaza por (missing)

# %%
# Aquí podemos ver que ya no estan como na sino como (missing)
df2 = pd.read_csv('NewData.csv', index_col=0)
df2
# Out:
#         COUNTRY      POP      AREA       GDP       CONT     IND_DAY
# CHN       China  1398.72   9596.96  12234.78       Asia   (missing)
# IND       India  1351.16   3287.26   2575.67       Asia  1947-08-15
# USA          US   329.74   9833.52  19485.39  N.America  1776-07-04
# IDN   Indonesia   268.07   1910.93   1015.54       Asia  1945-08-17
# BRA      Brazil   210.32   8515.77   2055.51  S.America  1822-09-07
# PAK    Pakistan   205.71    881.91    302.14       Asia  1947-08-14
# NGA     Nigeria   200.96    923.77    375.77     Africa  1960-10-01
# BGD  Bangladesh   167.09    147.57    245.63       Asia  1971-03-26
# RUS      Russia   146.79  17098.25   1530.75  (missing)  1992-06-12
# MEX      Mexico   126.58   1964.38   1158.23  N.America  1810-09-16
# JPN       Japan   126.22    377.97   4872.42       Asia   (missing)
# DEU     Germany    83.02    357.11   3693.20     Europe   (missing)
# FRA      France    67.02    640.68   2582.49     Europe  1789-07-14
# ...

# %%
#Aquí se le indica que los valores null son representados como '(missing)'
df2 = pd.read_csv('NewData.csv', index_col=0, na_values='(missing)')
df2
# Out:
#         COUNTRY      POP      AREA       GDP       CONT     IND_DAY
# CHN       China  1398.72   9596.96  12234.78       Asia         NaN
# IND       India  1351.16   3287.26   2575.67       Asia  1947-08-15
# USA          US   329.74   9833.52  19485.39  N.America  1776-07-04
# IDN   Indonesia   268.07   1910.93   1015.54       Asia  1945-08-17
# BRA      Brazil   210.32   8515.77   2055.51  S.America  1822-09-07
# PAK    Pakistan   205.71    881.91    302.14       Asia  1947-08-14
# NGA     Nigeria   200.96    923.77    375.77     Africa  1960-10-01
# BGD  Bangladesh   167.09    147.57    245.63       Asia  1971-03-26
# RUS      Russia   146.79  17098.25   1530.75        NaN  1992-06-12
# MEX      Mexico   126.58   1964.38   1158.23  N.America  1810-09-16
# JPN       Japan   126.22    377.97   4872.42       Asia         NaN
# DEU     Germany    83.02    357.11   3693.20     Europe         NaN
# FRA      France    67.02    640.68   2582.49     Europe  1789-07-14
# ...

# %% [markdown]
# ### Cambiando los tipos de datos de las columnas

# %%
df2.dtypes
# Out:
# COUNTRY     object
# POP        float64
# AREA       float64
# GDP        float64
# CONT        object
# IND_DAY     object
# dtype: object

# %%
df2.columns
# Out:
# Index(['COUNTRY', 'POP', 'AREA', 'GDP', 'CONT', 'IND_DAY'], dtype='object')

# %%
dtypes = {}
for col in df.columns[1:4]:
    value = input(f'Inserte el dtype que le quiere dar a {col}: ')
    dtypes.update({col: value})

# %%
print(dtypes)
# Out:
# {'POP': 'float32', 'AREA': 'float32', 'GDP': 'float32'}

# %%
#Indicando el dtype=  , y que parsee las fechas de la columna ['IND_DAY'] para que las lea como tipo datetime
df3 = pd.read_csv('dataDF.csv', index_col=0, parse_dates=['IND_DAY'], dtype=dtypes)
df3.dtypes
# Out:
# COUNTRY            object
# POP               float32
# AREA              float32
# GDP               float32
# CONT               object
# IND_DAY    datetime64[ns]
# dtype: object

# %%
#Podemos ver que la columna IND_DAY es de tipo datetime, e incuye valores NaT: Not a Time
df3.IND_DAY
# Out:
# CHN          NaT
# IND   1947-08-15
# USA   1776-07-04
# IDN   1945-08-17
# BRA   1822-09-07
# PAK   1947-08-14
# NGA   1960-10-01
# BGD   1971-03-26
# RUS   1992-06-12
# MEX   1810-09-16
# JPN          NaT
# DEU          NaT
# FRA   1789-07-14
# GBR          NaT
# ITA          NaT
# ARG   1816-07-09
# DZA   1962-07-05
# CAN   1867-07-01
# AUS          NaT
# KAZ   1991-12-16
# Name: IND_DAY, dtype: datetime64[ns]

# %% [markdown]
# ### Comprimiendo un archivo al exportarlo

# %%
df.to_csv('datazip.csv.zip')

# %% [markdown]
# #### Al leer un archivo comprimido, también se usa read_...() ya que pandas deduce el tipo de compresión

# %%
#Leyendo un csv comprimido
dfZip = pd.read_csv('datazip.csv.zip', index_col=0, parse_dates=['IND_DAY'])
dfZip
# Out:
#         COUNTRY      POP      AREA       GDP       CONT    IND_DAY
# CHN       China  1398.72   9596.96  12234.78       Asia        NaT
# IND       India  1351.16   3287.26   2575.67       Asia 1947-08-15
# USA          US   329.74   9833.52  19485.39  N.America 1776-07-04
# IDN   Indonesia   268.07   1910.93   1015.54       Asia 1945-08-17
# BRA      Brazil   210.32   8515.77   2055.51  S.America 1822-09-07
# PAK    Pakistan   205.71    881.91    302.14       Asia 1947-08-14
# NGA     Nigeria   200.96    923.77    375.77     Africa 1960-10-01
# BGD  Bangladesh   167.09    147.57    245.63       Asia 1971-03-26
# RUS      Russia   146.79  17098.25   1530.75        NaN 1992-06-12
# MEX      Mexico   126.58   1964.38   1158.23  N.America 1810-09-16
# JPN       Japan   126.22    377.97   4872.42       Asia        NaT
# DEU     Germany    83.02    357.11   3693.20     Europe        NaT
# FRA      France    67.02    640.68   2582.49     Europe 1789-07-14
# ...

# %% [markdown]
# ### Exportando el DF a un archivo excel ```.to_excel```

# %%
df.to_excel('dataExcel.xlsx', sheet_name='Países')

# %% [markdown]
# #### Leyendo el archivo excel

# %%
df_from_Excel = pd.read_excel('dataExcel.xlsx', sheet_name='Países', index_col=0, parse_dates=['IND_DAY'])
df_from_Excel
# Out:
#         COUNTRY      POP      AREA       GDP       CONT    IND_DAY
# CHN       China  1398.72   9596.96  12234.78       Asia        NaT
# IND       India  1351.16   3287.26   2575.67       Asia 1947-08-15
# USA          US   329.74   9833.52  19485.39  N.America 1776-07-04
# IDN   Indonesia   268.07   1910.93   1015.54       Asia 1945-08-17
# BRA      Brazil   210.32   8515.77   2055.51  S.America 1822-09-07
# PAK    Pakistan   205.71    881.91    302.14       Asia 1947-08-14
# NGA     Nigeria   200.96    923.77    375.77     Africa 1960-10-01
# BGD  Bangladesh   167.09    147.57    245.63       Asia 1971-03-26
# RUS      Russia   146.79  17098.25   1530.75        NaN 1992-06-12
# MEX      Mexico   126.58   1964.38   1158.23  N.America 1810-09-16
# JPN       Japan   126.22    377.97   4872.42       Asia        NaT
# DEU     Germany    83.02    357.11   3693.20     Europe        NaT
# FRA      France    67.02    640.68   2582.49     Europe 1789-07-14
# ...

# %%
df_from_Excel.dtypes
# Out:
# COUNTRY            object
# POP               float64
# AREA              float64
# GDP               float64
# CONT               object
# IND_DAY    datetime64[ns]
# dtype: object
